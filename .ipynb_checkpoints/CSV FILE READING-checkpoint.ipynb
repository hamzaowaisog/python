# %%
import pandas as pd
data = pd.read_csv('airlines_data_part.csv')
data.head(50)
# Out:
#           passenger_name  day  month  departure_city    arrival_city     sales
# 0   ALEKSANDRA KUZNECOVA   21      6          Moscow       Astrakhan   52000.0
# 1   ALEKSANDRA KUZNECOVA   21      6       Astrakhan          Moscow   52000.0
# 2         VIKTOR BORISOV   21      6          Moscow       Astrakhan   52000.0
# 3         VIKTOR BORISOV   21      6       Astrakhan          Moscow   52000.0
# 4      LYUDMILA POTAPOVA   21      6      Khabarovsk          Moscow  178800.0
# 5      LYUDMILA POTAPOVA   21      6     Novosibirsk          Moscow  178800.0
# 6      LYUDMILA POTAPOVA   21      6          Moscow     Novosibirsk  178800.0
# 7      LYUDMILA POTAPOVA   21      6          Moscow      Khabarovsk  178800.0
# 8      MAKSIM KUDRYASHOV   21      6     Novosibirsk            Perm  211100.0
# 9      MAKSIM KUDRYASHOV   21      6          Moscow            Perm  211100.0
# 10     MAKSIM KUDRYASHOV   21      6            Perm          Moscow  211100.0
# ...

# %%
data.columns #FINDING NAME OF ALL COLUMNS
# Out:
# Index(['passenger_name', 'day', 'month', 'departure_city', 'arrival_city',
#        'sales'],
#       dtype='object')

# %%
data.passenger_name #USING COLUMNS TO DISPLAY DATA
# Out:
# 0          ALEKSANDRA KUZNECOVA
# 1          ALEKSANDRA KUZNECOVA
# 2                VIKTOR BORISOV
# 3                VIKTOR BORISOV
# 4             LYUDMILA POTAPOVA
#                    ...
# 1016593        DMITRIY MELNIKOV
# 1016594           VASILIY FOMIN
# 1016595           VASILIY FOMIN
# 1016596         VALERIY MOISEEV
# 1016597         VALERIY MOISEEV
# Name: passenger_name, Length: 1016598, dtype: object

# %%
data #DISPLAYING ALL THE DATA
# Out:
#                passenger_name  day  month departure_city arrival_city  \
# 0        ALEKSANDRA KUZNECOVA   21      6         Moscow    Astrakhan
# 1        ALEKSANDRA KUZNECOVA   21      6      Astrakhan       Moscow
# 2              VIKTOR BORISOV   21      6         Moscow    Astrakhan
# 3              VIKTOR BORISOV   21      6      Astrakhan       Moscow
# 4           LYUDMILA POTAPOVA   21      6     Khabarovsk       Moscow
# ...                       ...  ...    ...            ...          ...
# 1016593      DMITRIY MELNIKOV   15      8        Bryansk       Moscow
# 1016594         VASILIY FOMIN   15      8         Moscow      Bryansk
# 1016595         VASILIY FOMIN   15      8        Bryansk       Moscow
# 1016596       VALERIY MOISEEV   15      8         Moscow      Bryansk
# 1016597       VALERIY MOISEEV   15      8        Bryansk       Moscow
#
#              sales
# 0          52000.0
# 1          52000.0
# 2          52000.0
# 3          52000.0
# 4         178800.0
# ...

# %%
data1 = data[['passenger_name','day','arrival_city']] #DISPLAYING ONLY COLUMNS WE WANT

# %%
data1
# Out:
#                passenger_name  day arrival_city
# 0        ALEKSANDRA KUZNECOVA   21    Astrakhan
# 1        ALEKSANDRA KUZNECOVA   21       Moscow
# 2              VIKTOR BORISOV   21    Astrakhan
# 3              VIKTOR BORISOV   21       Moscow
# 4           LYUDMILA POTAPOVA   21       Moscow
# ...                       ...  ...          ...
# 1016593      DMITRIY MELNIKOV   15       Moscow
# 1016594         VASILIY FOMIN   15      Bryansk
# 1016595         VASILIY FOMIN   15       Moscow
# 1016596       VALERIY MOISEEV   15      Bryansk
# 1016597       VALERIY MOISEEV   15       Moscow
#
# [1016598 rows x 3 columns]

# %%
data.tail(20) #DISPLAYING LAST 20 DATAS
# Out:
#              passenger_name  day  month     departure_city       arrival_city  \
# 1016578       MARAT KAZAKOV   15      8             Moscow  Yuzhno-Sakhalinsk
# 1016579       STEPAN IVANOV   15      8  Yuzhno-Sakhalinsk             Moscow
# 1016580       STEPAN IVANOV   15      8             Moscow  Yuzhno-Sakhalinsk
# 1016581    KSENIYA DANILOVA   15      8  Yuzhno-Sakhalinsk             Moscow
# 1016582    KSENIYA DANILOVA   15      8             Moscow  Yuzhno-Sakhalinsk
# 1016583    DMITRIY YAKOVLEV   15      8  Yuzhno-Sakhalinsk             Moscow
# 1016584    DMITRIY YAKOVLEV   15      8             Moscow  Yuzhno-Sakhalinsk
# 1016585    ZINAIDA KISELEVA   15      8  Yuzhno-Sakhalinsk             Moscow
# 1016586    ZINAIDA KISELEVA   15      8             Moscow  Yuzhno-Sakhalinsk
# 1016587   TATYANA TROFIMOVA   15      8             Moscow  Yuzhno-Sakhalinsk
# 1016588   TATYANA TROFIMOVA   15      8  Yuzhno-Sakhalinsk             Moscow
# ...

# %%
display(data.iloc[6]) #DISPLAYING DATA ONLY OF ROW 6
# Out:
# passenger_name    LYUDMILA POTAPOVA
# day                              21
# month                             6
# departure_city               Moscow
# arrival_city            Novosibirsk
# sales                      178800.0
# Name: 6, dtype: object

# %%
data.rank() #SHOWING THE RANK OF ALL THE DATAS
# Out:
#          passenger_name       day     month  departure_city  arrival_city  \
# 0               59875.5  765100.0   13781.0        413791.5       18649.0
# 1               59875.5  765100.0   13781.0         18253.5      411726.5
# 2              899930.5  765100.0   13781.0        413791.5       18649.0
# 3              899930.5  765100.0   13781.0         18253.5      411726.5
# 4              476526.0  765100.0   13781.0        142368.0      411726.5
# ...                 ...       ...       ...             ...           ...
# 1016593        230624.0  625435.5  844081.5         46869.0      411726.5
# 1016594        881419.0  625435.5  844081.5        413791.5       47538.5
# 1016595        881419.0  625435.5  844081.5         46869.0      411726.5
# 1016596        871331.5  625435.5  844081.5        413791.5       47538.5
# 1016597        871331.5  625435.5  844081.5         46869.0      411726.5
#
#              sales
# 0         327726.0
# 1         327726.0
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of                passenger_name  day  month departure_city arrival_city  \
# 0        ALEKSANDRA KUZNECOVA   21      6         Moscow    Astrakhan
# 1        ALEKSANDRA KUZNECOVA   21      6      Astrakhan       Moscow
# 2              VIKTOR BORISOV   21      6         Moscow    Astrakhan
# 3              VIKTOR BORISOV   21      6      Astrakhan       Moscow
# 4           LYUDMILA POTAPOVA   21      6     Khabarovsk       Moscow
# ...                       ...  ...    ...            ...          ...
# 1016593      DMITRIY MELNIKOV   15      8        Bryansk       Moscow
# 1016594         VASILIY FOMIN   15      8         Moscow      Bryansk
# 1016595         VASILIY FOMIN   15      8        Bryansk       Moscow
# 1016596       VALERIY MOISEEV   15      8         Moscow      Bryansk
# 1016597       VALERIY MOISEEV   15      8        Bryansk       Moscow
#
#              sales
# 0          52000.0
# 1          52000.0
# 2          52000.0
# ...

# %%
#PYTHON WEBBROWSER MODULE

# %%
import webbrowser

# %%
website = 'https://pandas.pydata.org'
webbrowser.open(website)
# Out:
# True
